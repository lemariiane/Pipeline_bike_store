# %%
df_brands=spark.read.csv('/Volumes/workspace/1bronze_bike/raw_data/brands.csv',
                        header=True,
                        inferSchema=True,
                        sep=',')
display(df_brands)

# %%
df_brands.write\
    .mode('overwrite')\
    .format('delta')\
    .option('mergeSchema','true')\
    .saveAsTable('1bronze_bike.brands')
#df_stores.createOrReplaceTempView("temp_bronze_brands")

# %%
# %sql
select * from 1bronze_bike.brands
