# %%
df_customers=spark.read.csv('/Volumes/workspace/1bronze_bike/raw_data/customers.csv',
                        header=True,
                        inferSchema=True,
                        sep=',')
display(df_customers)

# %%
df_customers.write\
    .mode('overwrite')\
    .format('delta')\
    .option('mergeSchema','true')\
    .saveAsTable('1bronze_bike.customers')

# %%
# %sql
select * from 1bronze_bike.customers
